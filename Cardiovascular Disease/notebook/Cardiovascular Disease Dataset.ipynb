# %% [markdown]
# # Problema de Négocio

# %% [markdown]
# **A Empresa Cardio Catch Diseases ( CCD )**
#
# A Cadio Catch Diseases é uma empresa especializada em detecção de doenças cardíacas em estágios iniciais. O seu modelo de negócio é do tipo Serviço, ou seja, a empresa ofereço o diagnóstico precoce de uma doença cardiovascular por um certo preço.
#
# Atualmente, o diagnóstico de uma doença cardiovascular é feita manualmente por uma equipe de especialistas. A precisão atual do diagnóstico varia entre 55% e 65%, devido a complexidade do diagnóstico e também da fadiga da equipe que se revezam em turnos para minimizar os riscos. O custo de cada diagnóstico, incluindo os aparelhos e a folha de pagamento dos analistas, gira em torno de R$ 1.000,00.
#
# O preço do diagnóstico, pago pelo cliente, varia de acordo com a precisão conseguida pelo time de especialistas, o cliente paga 500 Reais a cada 5% de acurácia acima de 50%. Por exemplo, para uma precisão de 55%, o diagnóstico custa 500 reais para o cliente, para uma precisão de 60%, o valor é de R$ 1000,00 e assim por diante. Se a precisão do diagnóstico for 50%. o cliente não paga por ele.
#
# Observe que a variação da precisão dada pelo time de especialistas, faz com que a empresa tenha ora uma operação com lucro, receita maior que o custo, ora uma operação com prejuízo, receita menor que o custo. Essa instabilidade do diagnóstico faz com que a empresa tenha um Cashflow imprevisível.
#
# O seu objetivo como o Cientista de Dados contratado pela Cardio Catch Diseases é criar uma ferramenta que aumente a precisão do diagnóstico e que essa precisão seja estável para todos os diagnósticos.
#
# Portanto o seu trabalho como Data Scientist é criar um ferramenta de classificação de doentes, como uma precisão estável. Junto com a ferramenta, você precisa enviar um relatório para o CEO da Cardio Catch Diseases, reportando os resultados e respondendo às seguintes perguntas: ( Ele provavelmente irá fazer essas pergunta no dia da sua apresentação. )
#
# - Qual a Acurácia e a Precisão da ferramenta?
# - Quanto lucro a Cardio Catch Diseases passará a ter com a nova ferramenta?
# - Qual a Confiabilidade do resultado dados pela nova ferramenta?

# %% [markdown]
# # 0.0 Importações

# %%
import pandas             as pd
import seaborn            as sns
import matplotlib.pyplot  as plt
import scikitplot         as skplt
import numpy              as np
import matplotlib.patches as mpatches
import pickle
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV, KFold, GridSearchCV
from sklearn.metrics         import confusion_matrix, classification_report, roc_curve, plot_confusion_matrix, brier_score_loss
from sklearn.metrics         import roc_auc_score, make_scorer, accuracy_score, precision_score, recall_score, f1_score
from IPython.display         import Image
from sklearn.ensemble        import RandomForestClassifier
from sklearn.preprocessing   import RobustScaler, MinMaxScaler, LabelEncoder, StandardScaler
from sklearn.ensemble        import GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.neighbors       import KNeighborsClassifier
from sklearn.linear_model    import LogisticRegression, SGDClassifier
from sklearn.dummy           import DummyClassifier
from sklearn.tree            import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_validate
from lightgbm                import LGBMClassifier
from boruta                  import BorutaPy
from scipy.stats             import mannwhitneyu, wilcoxon
from sklearn                 import metrics
from scipy                   import stats

# %% [markdown]
# ## 0.1 Funções

# %%
def obesity(coluna):
    if coluna <= 18.5:
        return 'Baixo Peso'
    elif coluna >18.5 and coluna <=24.9:
        return 'Peso Normal'
    elif coluna >25 and coluna <=29.9:
        return 'Pré Obeso'
    elif coluna >30 and coluna <=34.9:
        return 'Obesidade I'
    elif coluna >35 and coluna <=39.9:
        return 'Obesidade II'
    else:
        return 'Obesidade III'

# %%
def factors_risk_active(cols):
    sum_of_factors = cols[0]
    active = cols[1]
    
    if sum_of_factors > 3 and active == 0:
        return 'Não faz atividade - 2 comorbidade'
    if sum_of_factors == 3 and active == 0:
        return 'Não faz atividade - 1 comorbidade'
    if sum_of_factors == 2 and active == 0:
        return 'Não faz atividade - Nenhuma comorbidade'
    if sum_of_factors > 3 and active == 1:
        return 'Faz atividade - 2 comorbidade'
    if sum_of_factors == 3 and active == 1:
        return 'Faz atividade - 1 comorbidade'
    else:
        return 'Faz atividade - Nenhuma comorbidade'

# %%
def bad_habits_active(cols):
    bad_habits = cols[0]
    active = cols[1]
    
    if bad_habits == 2 and active == 0:
        return 'Não faz atividade - 2 maus hábitos'
    if bad_habits == 1 and active == 0:
        return 'Não faz atividade - 1 mau hábitos'
    if bad_habits == 0 and active == 0:
        return 'Não faz atividade - Nenhum mau hábitos'
    if bad_habits == 2 and active == 1:
        return 'Faz atividade - 2 maus hábitos'
    if bad_habits == 1 and active == 1:
        return 'Faz atividade - 1 mau hábitos'
    else:
        return 'Faz atividade - Nenhum mau hábitos'

# %%
# Função para calculo de métricas dos Modelos.
def ml_error(model_name,modelo, X_train, y_train):
    scoring = {'accuracy' : make_scorer(accuracy_score), 
               'precision' : make_scorer(precision_score),
               'recall' : make_scorer(recall_score), 
               'f1_score' : make_scorer(f1_score),
               'roc_auc_score' : make_scorer(roc_auc_score)}
    
    
    kfold = KFold(n_splits=5)
    model = modelo 
    
    scores = cross_validate(estimator=model, X=X_train, y=y_train, cv=kfold,scoring=scoring)
    
    return pd.DataFrame({'Model_Name':model_name,
                        'Acuracia':(scores['test_accuracy'].mean()),
                        'Precision': (scores['test_precision'].mean()),
                        'Recall': (scores['test_recall'].mean()),
                         'ROC_AUC':(scores['test_roc_auc_score'].mean()),
                        'F1':(scores['test_f1_score'].mean())},index=[0])

# %%
# Multiplas Matriz de Confusão.
def multiple_confusion_matrix(classifiers, X_train, X_test):
    for cls in classifiers:
        cls.fit(X_train, y_train)

    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(14,4))

    for cls, ax in zip(classifiers, axes.flatten()):
        plot_confusion_matrix(cls, 
                              X_test, 
                              y_test, 
                              ax=ax, 
                              cmap='Greens', normalize='true')
        ax.title.set_text(type(cls).__name__)  

    plt.tight_layout()  
    plt.show()

# %% [markdown]
# # 1.0 - Análise Descritiva

# %%
df = pd.read_csv('cardio_train.csv', sep = ";")

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df.shape
# Out:
# (70000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
df.describe().T
# Out:
#                count          mean           std      min       25%      50%  \
# id           70000.0  49972.419900  28851.302323      0.0  25006.75  50001.5
# age          70000.0  19468.865814   2467.251667  10798.0  17664.00  19703.0
# gender       70000.0      1.349571      0.476838      1.0      1.00      1.0
# height       70000.0    164.359229      8.210126     55.0    159.00    165.0
# weight       70000.0     74.205690     14.395757     10.0     65.00     72.0
# ap_hi        70000.0    128.817286    154.011419   -150.0    120.00    120.0
# ap_lo        70000.0     96.630414    188.472530    -70.0     80.00     80.0
# cholesterol  70000.0      1.366871      0.680250      1.0      1.00      1.0
# gluc         70000.0      1.226457      0.572270      1.0      1.00      1.0
# smoke        70000.0      0.088129      0.283484      0.0      0.00      0.0
# alco         70000.0      0.053771      0.225568      0.0      0.00      0.0
# active       70000.0      0.803729      0.397179      0.0      1.00      1.0
# cardio       70000.0      0.499700      0.500003      0.0      0.00      0.0
#
#                   75%      max
# id           74889.25  99999.0
# age          21327.00  23713.0
# gender           2.00      2.0
# height         170.00    250.0
# weight          82.00    200.0
# ap_hi          140.00  16020.0
# ap_lo           90.00  11000.0
# cholesterol      2.00      3.0
# gluc             1.00      3.0
# smoke            0.00      1.0
# alco             0.00      1.0
# active           1.00      1.0
# cardio           1.00      1.0

# %% [markdown]
# ## 1.2 Verificando valores faltantes

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %% [markdown]
# # 2.0 Feature Engineering

# %%
# conversão de dias da idade para anos
df['age'] = df['age'].apply( lambda x: round(x/365))

# soma dos fatores de risco
df['sum of factors'] = df['cholesterol'] + df['gluc']

# soma dos maus hábitos 
df['bad habits'] = df['smoke'] + df['alco']

# Influência da atividade física nos fatores de risco
df['influence comorbid activities'] = df[['sum of factors', 'active']].apply(factors_risk_active, axis=1)

# Influencia da atividade física nos maus hábitos
df['influence bad habits activities'] = df[['bad habits', 'active']].apply(bad_habits_active, axis=1)

# Calculando IMC
df['imc'] = df['weight'] / ((df['height']/100) * (df['height']/100))

#Calculando grau de obesidade
df['obesity'] = df['imc'].apply(obesity)

#Pressão alta dividida por pressão baixa
df['hi_per_low'] = df['ap_hi'] / df['ap_lo']

# %%
df.head()
# Out:
#    id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0   50       2     168    62.0    110     80            1     1      0
# 1   1   55       1     156    85.0    140     90            3     1      0
# 2   2   52       1     165    64.0    130     70            3     1      0
# 3   3   48       2     169    82.0    150    100            1     1      0
# 4   4   48       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio  sum of factors  bad habits  \
# 0     0       1       0               2           0
# 1     0       1       1               4           0
# 2     0       0       1               4           0
# 3     0       1       1               2           0
# 4     0       0       0               2           0
#
#              influence comorbid activities  \
# 0      Faz atividade - Nenhuma comorbidade
# 1            Faz atividade - 2 comorbidade
# 2        Não faz atividade - 2 comorbidade
# 3      Faz atividade - Nenhuma comorbidade
# 4  Não faz atividade - Nenhuma comorbidade
#
#           influence bad habits activities        imc        obesity  \
# 0      Faz atividade - Nenhum mau hábitos  21.967120    Peso Normal
# 1      Faz atividade - Nenhum mau hábitos  34.927679  Obesidade III
# 2  Não faz atividade - Nenhum mau hábitos  23.507805    Peso Normal
# 3      Faz atividade - Nenhum mau hábitos  28.710479      Pré Obeso
# 4  Não faz atividade - Nenhum mau hábitos  23.011177    Peso Normal
#
#    hi_per_low
# 0    1.375000
# 1    1.555556
# 2    1.857143
# 3    1.500000
# 4    1.666667

# %% [markdown]
# # 2.0 Limpeza dos dados

# %%
# Somente pessoas com pressão alta entre 68 e 220
df = df[(df['ap_hi']>68) & (df['ap_hi'] < 220)]

# Somente pessoas com pressão baixa entre 60 e 160 
df = df[(df['ap_lo']>60) & (df['ap_lo'] < 160)]

# %% [markdown]
# # 3.0 Mapa Mental de hipoteses

# %% [markdown]
# ## 3.1 Mapa mental

# %%
Image ('img\Doenas_no_corao.png')

# %% [markdown]
# ## Hipoteses

# %% [markdown]
# **H1** - Pessoas com mais de 60 anos tem duas vezes mais chances de ter problema no coração do que uma pessoa com menos de 60 anos.
#
# **H2** - Em média, um gênero tem mais chances de ter problema no coração do que o outro.
#
# **H3** - Pressão alta acima de 140 aumenta duas vezes o risco de ter problema no coração.
#
# **H4** - Pressão baixa acima de 80 aumenta duas vezes o risco de ter problema no coração.
#
# **H5** - Colesterol alto é um fator importante para problemas no coração.
#
# **H6** - Pessoas que fumam tem 2 vezes mais chances de ter um problema no coração.
#
# **H7** - O Alcool não é um fator importante para quem doenças no coração.
#
# **H8** - Pessoas ativas tem menos chances de desenvolver um  problema no coração.
#
# **H9** - Pessoas que acumulam Colesterol e/ou Glicose e/ou fumam e/ou bebem tem o dobro de pessoas que não tem essas características.
#
# **H10** - Pessoas com grau de obesidade acima de 2 tem duas vezes mais chances de ter problema no coração.

# %% [markdown]
# # 4.0 Análise exploratória

# %% [markdown]
# ##  4.1 - Análise Univariada

# %% [markdown]
# ### 4.1.0 -  Variável Resposta - Cardio

# %%
# Variável resposta
plt.figure(figsize=(18,6))
sns.countplot(x='cardio', data=df, palette='gist_rainbow');
plt.title('Gráfico - Não tem problema Cardíaco x Tem problema Cardíaco', fontsize=20)
plt.xlabel("Não x Sim", fontsize=15)
plt.ylabel("Quantidade", fontsize=12);

# %% [markdown]
# **Anotações Importantes**
#
# - Os dados da variável resposta estão balanceados.

# %% [markdown]
# ### 4.1.1 - Variável  Age - Idade

# %%
plt.figure(figsize=(18,6))
plt.subplot(1,3,1)
sns.boxplot(x='cardio', y='age', data=df, palette='icefire');
plt.title('Média de idade')
plt.xlabel("Problema cardíaco")
plt.ylabel("Idade")

plt.subplot(1,3,2)
aux00 = df.loc[df['cardio'] == 0, 'age']
sns.histplot(aux00, palette='icefire')
plt.title('Distribuição - Não tem problemas cardíacos')
plt.xlabel("Idade")
plt.ylabel("Total")

plt.subplot(1,3,3)
aux01 = df.loc[df['cardio'] == 1, 'age']
sns.histplot(aux01, palette='icefire');
plt.title('Distribuição - Tem problemas cardíacos')
plt.xlabel("Idade")
plt.ylabel("Total");

# %% [markdown]
# **Teste de Hipótese**
#
# A distribuição das idades de quem tem problemas cardíacos e de quem não tem são:
#
# **<p>H0** - A distribuição é igual</p>
# **H1** - A distribuição é diferente
#
# **Teste U de Mann-Whitney**

# %%
_, p = mannwhitneyu(aux00, aux01)
alpha = 0.05
if p > alpha:
    print('O valor de p é {}, por tanto as distribuições são iguais (falha ao rejeitar H0)'.format(p))
else:
    print('O valor de p é {}, portanto as distribuições são diferentes (rejeitar H0)'.format(p))
# Out:
# O valor de p é 0.0, portanto as distribuições são diferentes (rejeitar H0)

# %% [markdown]
# **Anotações Importantes**
#
# - Os pacientes que possuem doenças cardíacas possuem uma média de idade maior do que os pacientes que não possuem.
# - A Distribuição das idades de quem possui e de quem não possui doença cardíaca é diferente (indica ser uma boa variável).

# %% [markdown]
# ### 4.1.2 - Variável Gender - Gênero

# %%
plt.figure(figsize=(18,6))
sns.countplot(x='gender', data=df, palette='rocket_r');
plt.title('Gráfico - Genêro', fontsize=20)
plt.xlabel("Genêro", fontsize=15)
plt.ylabel("Quantidade", fontsize=12);

# %%
plt.figure(figsize=(18,6))
sns.countplot(x='gender', hue='cardio', data=df);
plt.title('Gráfico - Genêro', fontsize=20)
plt.xlabel("Genêro", fontsize=15)
plt.ylabel("Quantidade", fontsize=12);

# %% [markdown]
# **Anotações Importantes**
#
# - O dataset tem mais exemplos de um dos genêros.

# %% [markdown]
# ### 3.1.3 - Variável Weight - Peso

# %%
plt.figure(figsize=(18,6))
plt.subplot(1,3,1)
sns.boxplot(x='cardio', y='weight', data=df, palette='viridis');
plt.title('Média de Peso', fontsize=20)
plt.xlabel("Não x Sim", fontsize=15)
plt.ylabel("KG", fontsize=12);

plt.subplot(1,3,2)
aux00 = df.loc[df['cardio'] == 0, 'weight']
sns.histplot(aux00)
plt.title('Distribuição - Não tem problema cardíaco', fontsize=15)
plt.xlabel("KG", fontsize=15)
plt.ylabel("Quantidade", fontsize=12);

plt.subplot(1,3,3)
aux01 = df.loc[df['cardio'] == 1, 'weight']
sns.histplot(aux01);
plt.title('Distribuição - Tem problema cardíaco', fontsize=15)
plt.xlabel("KG", fontsize=15)
plt.ylabel("Quantidade", fontsize=12);

# %% [markdown]
# **Teste de Hipótese**
#
# A distribuição das idades de quem tem problemas cardíacos e de quem não tem são:
#
# **<p>H0** - A distribuição é igual</p>
# **H1** - A distribuição é diferente
#
# **Teste U de Mann-Whitney**

# %%
_, p = mannwhitneyu(aux00, aux01)
alpha = 0.05
if p > alpha:
    print('O valor de p é {}, por tanto as distribuições são iguais (falha ao rejeitar H0)'.format(p))
else:
    print('O valor de p é {}, portanto as distribuições são diferentes (rejeitar H0)'.format(p))
# Out:
# O valor de p é 0.0, portanto as distribuições são diferentes (rejeitar H0)

# %% [markdown]
# **Anotações Importantes**
#
# - Media dos KG de quem tem problema no coração é maior.
# - A Distribuição do peso de quem tem problemas cardíacos e de quem não tem problemas cardíacos é diferente.
# - O peso de quem tem problema no coração tem diferença estatísticamente significativa.

# %% [markdown]
# ### 3.1.4 - Variável Height - Altura

# %%
plt.figure(figsize=(18,6))
plt.subplot(1,3,1)
sns.boxplot(x='cardio', y='height', data=df, palette='YlOrBr');
plt.title('Média de altura', fontsize=20)
plt.xlabel("Não x Sim", fontsize=15)
plt.ylabel("Centimetros", fontsize=12);

plt.subplot(1,3,2)
aux00 = df.loc[df['cardio'] == 0, 'height']
sns.histplot(aux00)
plt.title('Distribuição - Não tem problema cardíaco', fontsize=15)
plt.xlabel("Centimetros", fontsize=15)
plt.ylabel("Quantidade", fontsize=12);

plt.subplot(1,3,3)
aux01 = df.loc[df['cardio'] == 1, 'height']
sns.histplot(aux01);
plt.title('Distribuição - Tem problema cardíaco', fontsize=15)
plt.xlabel("KG", fontsize=15)
plt.ylabel("Centimetros", fontsize=12);

# %% [markdown]
# **Teste de Hipótese**
#
# A distribuição das idades de quem tem problemas cardíacos e de quem não tem são:
#
# **<p>H0** - A distribuição é igual</p>
# **H1** - A distribuição é diferente
#
# **Teste U de Mann-Whitney**

# %%
_, p = mannwhitneyu(aux00, aux01)
alpha = 0.05
if p > alpha:
    print('O valor de p é {}, por tanto as distribuições são iguais (falha ao rejeitar H0)'.format(p))
else:
    print('O valor de p é {}, portanto as distribuições são diferentes (rejeitar H0)'.format(p))
# Out:
# O valor de p é 6.243253744352673e-08, portanto as distribuições são diferentes (rejeitar H0)

# %% [markdown]
# **Anotações Importantes**
#
# - Parece haver Outlier na varíavel Height.
# - A Media da altura de quem tem problema no coração é igual.
# - A Distribuição das alturas de quem tem problemas cardíacos e de quem não tem problemas cardíacos é diferente.

# %% [markdown]
# ### 3.1.5 - Variáveis ap_hi, ap_lo e age - Pressão alta, Pressão Baixa e Idade

# %% [markdown]
# **Filtrar apenas quem tem pressão alta entre 68 e 220 e quem tem pressão baixa entre 60 e 160.**

# %%
plt.figure(figsize=(18,5))
plt.subplot(1,2,1)
sns.scatterplot(x='ap_hi', y='age', hue='cardio', data=df, palette='deep');
plt.title('Dispersão - Pressão alta x Idade', fontsize=20)
plt.xlabel("Pressão Alta", fontsize=15)
plt.ylabel("Idade", fontsize=15);


plt.subplot(1,2,2)
sns.scatterplot(x='ap_lo', y='age', hue='cardio', data=df, palette='deep');
plt.title('Dispersão - Pressão Baixa x Idade', fontsize=20)
plt.xlabel("Pressão Baixa", fontsize=15)
plt.ylabel("Idade", fontsize=15);

# %% [markdown]
# **Anotações Importantes**
#
# - Quem tem pressão alta maior parece ter mais chances de ter problemas no coração.
# - Quem tem uma pressão baixa menor e uma idade menor tem mais chances de NÃO ter problemas no coração.

# %%
plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
sns.distplot(df['ap_lo']);
plt.title('Distribuição Pressão Baixa', fontsize=20)
plt.xlabel("Pressão Baixa", fontsize=15)
plt.ylabel("Densidade", fontsize=15);

plt.subplot(1,2,2)
sns.distplot(df['ap_hi']);
plt.title('Distribuição Pressão Alta', fontsize=20)
plt.xlabel("Pressão Baixa", fontsize=15)
plt.ylabel("Densidade", fontsize=15);

# %%
plt.figure(figsize=(18,6))
sns.kdeplot(df[df['cardio']==0]['ap_hi'], shade=True, color='orange')
sns.kdeplot(df[df['cardio']==1]['ap_hi'], shade=True, color='green')
handles = [mpatches.Patch(facecolor=plt.cm.Oranges(100), label="Não tem problema cardíaco"),
           mpatches.Patch(facecolor=plt.cm.Greens(100), label="Tem problema cardíaco")]
plt.legend(handles=handles);
plt.title('Densidade - Gráfico Pressão Alta', fontsize=20)
plt.xlabel("Pressão Alta", fontsize=15)
plt.ylabel("Densidade de pessoas", fontsize=15);

# %%
plt.figure(figsize=(18,6))
sns.kdeplot(df[df['cardio']==0]['ap_lo'], shade=True, color='red')
sns.kdeplot(df[df['cardio']==1]['ap_lo'], shade=True, color='blue')
handles = [mpatches.Patch(facecolor=plt.cm.Reds(100), label="Não tem problema cardíaco"),
           mpatches.Patch(facecolor=plt.cm.Blues(100), label="Tem problema cardíaco")]
plt.legend(handles=handles);
plt.title('Densidade - Gráfico Pressão Baixa', fontsize=20)
plt.xlabel("Pressão Baixa", fontsize=15)
plt.ylabel("Densidade de pessoas", fontsize=15);

# %% [markdown]
# **Anotações Importantes**
#
# - Quem tem problemas cardíacos tem sempre pressão alta e pressão baixa maior dos que não tem.

# %%
plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
sns.boxplot(x='cardio', y='ap_lo', data=df);
plt.title('Media Pressão Baixa', fontsize=20)
plt.xlabel("Problema Cardíaco - Não X Sim", fontsize=15)
plt.ylabel("Pressão Baixa", fontsize=15);

plt.subplot(1,2,2)
sns.boxplot(x='cardio', y='ap_hi', data=df);
plt.title('Media Pressão Alta', fontsize=20)
plt.xlabel("Problema Cardíaco - Não X Sim", fontsize=15)
plt.ylabel("Pressão Alta", fontsize=15);

# %% [markdown]
# **Anotações Importantes**
#
# - Quem tem problemas cardíacos tem uma pressão alta e uma pressão baixa maior em média.

# %% [markdown]
# ### 3.1.6 - Variável Cholesterol - Colesterol

# %%
plt.figure(figsize=(18,5))
plt.subplot(1,3,1)
sns.countplot(x = 'cholesterol', data=df,palette='deep')
plt.xlabel('Colesterol')
plt.ylabel('Quantidade');

plt.subplot(1,3,2)
sns.violinplot(x='cholesterol', y='ap_hi', hue='cardio', data=df);
               
plt.subplot(1,3,3)
sns.violinplot(x='cholesterol', y='ap_lo', hue='cardio', data=df);

# %%
plt.figure(figsize=(18,6))
sns.kdeplot(df[df['cholesterol']==1]['weight'], shade=True, color='red')
sns.kdeplot(df[df['cholesterol']==2]['weight'], shade=True, color='blue')
sns.kdeplot(df[df['cholesterol']==3]['weight'], shade=True, color='purple')
handles = [mpatches.Patch(facecolor=plt.cm.Reds(100), label="Normal"),
           mpatches.Patch(facecolor=plt.cm.Blues(100), label="Acima do Normal"),
           mpatches.Patch(facecolor=plt.cm.Purples(100), label="Muito acima do Normal")]
plt.legend(handles=handles);
plt.title('Densidade - Gráfico Pressão Baixa', fontsize=20)
plt.xlabel("Peso", fontsize=15)
plt.ylabel("Densidade de pessoas", fontsize=15);

# %% [markdown]
# ### 3.1.7 - Variável Gluc - Glicose

# %%
plt.figure(figsize=(18,5))
plt.subplot(1,3,1)
sns.countplot(x='gluc', data=df, palette='rainbow');

plt.subplot(1,3,2)
sns.violinplot(x='gluc', y='ap_hi', hue='cardio', data=df, palette='rainbow')

plt.subplot(1,3,3)
sns.violinplot(x='gluc', y='ap_lo', hue='cardio', data=df, palette='rainbow');

# %% [markdown]
# ### 3.1.8 - Variável Smoke - Cigarro

# %% [markdown]
# A Grande maioria das pessoas da base de dados não fumam.

# %%
plt.figure(figsize=(18,5))
plt.subplot(1,3,1)
sns.countplot(x='smoke', data=df);

plt.subplot(1,3,2)
sns.violinplot(x='smoke', y='ap_hi', hue='cardio', data=df);

plt.subplot(1,3,3)
sns.violinplot(x='smoke', y='ap_lo', hue='cardio', data=df);

# %% [markdown]
# ### 3.1.9 Variável Alco - Álcool

# %% [markdown]
# A Grande maioria das pessoas da base de dados não bebem alcool.

# %%
sns.countplot(x='alco', data=df, palette='terrain_r');
plt.title('Pacientes que consomem Álcool')
plt.xlabel('Álcool')
plt.ylabel('Total');

# %%
plt.figure(figsize=(18,12))
plt.subplot(2,3,1)
sns.boxplot(x='alco', y='ap_lo', hue='cardio', data=df, palette='muted');
plt.title('Boxplot Álcool x Pressão Baixa')
plt.xlabel('Álcool')
plt.ylabel('Pressão Baixa');

plt.subplot(2,3,2)
sns.boxplot(x='alco', y='ap_hi', hue='cardio', data=df, palette='bright');
plt.title('Boxplot Álcool x Pressão Alta')
plt.xlabel('Álcool')
plt.ylabel('Pressão Alta');

plt.subplot(2,3,3)
sns.boxplot(x='alco', y='age', hue='cardio', data=df, palette='bright');
plt.title('Boxplot Álcool x Idade')
plt.xlabel('Álcool')
plt.ylabel('Idade');

plt.subplot(2,3,4)
sns.boxplot(x='alco', y='weight', hue='cardio', data=df, palette='deep');
plt.title('Boxplot Álcool x Peso')
plt.xlabel('Álcool')
plt.ylabel('Peso');

plt.subplot(2,3,5)
sns.boxplot(x='alco', y='height', hue='cardio', data=df, palette='Blues_r');
plt.title('Boxplot Álcool x Altura')
plt.xlabel('Álcool')
plt.ylabel('Altura');

plt.subplot(2,3,6)
aux = df[(df['imc']<60)]
sns.boxplot(x='alco', y='imc', hue='cardio', data=aux, palette='mako_r');
plt.title('Boxplot Álcool x IMC')
plt.xlabel('Álcool')
plt.ylabel('IMC');

# %% [markdown]
# - Poucas pessoas da base de dados consomem alcool, então essa varíavel sozinha não parece ter efeito em doenças no coração.
#
# - Quem tem doença no coração normalmente tem: Mais idade, uma maior pressão alta, uma maior pressão baixa e mais peso.
#
# - A altura não parece influenciar em nada sozinha.

# %% [markdown]
# ### 3.1.10 - Variável Active - Atividade Física

# %%
fig, ax = plt.subplots(1, 2, figsize=(18,4))
sns.countplot(x='active', data=df, ax=ax[0], palette="PuOr");
ax[0].set_title('Gráfico - Atividade Física - Não X Atividade Física - Sim')
ax[0].set_xlabel('Atividade Física')
ax[0].set_ylabel('Total')
fig.suptitle('Gráficos de Atividade Física', fontsize=14)

df2 = df[['active', 'cardio']].groupby('active').count().reset_index()
hue0 = df[(df['active']==0) & (df['cardio']==1)].shape[0]
hue1 = df[(df['active']==1) & (df['cardio']==1)].shape[0]
hue = pd.DataFrame([hue0, hue1])
df3 = pd.concat([df2, hue], axis=1)
df3['media'] = df3[0]/df3['cardio']
df3 = df3[['active', 'media']]
df3.set_index('active',inplace=True)
df3.plot.bar(ax=ax[1], color='purple');
ax[1].set_title('Gráfico Média - Pessoas que tem doença no coração')
ax[1].set_xlabel('Atividade Física')
ax[1].set_ylabel('Total');

# %% [markdown]
# A Grande maioria das pessoas do dataset fazem atividade física, porém em média, quem tem doença no coração não faz atividade física. Isso por si só não explica muita coisa, pois quem tem doença no coração pode não fazer atividade por outros motivos como obesidade, idade, etc.

# %%
plt.figure(figsize=(18,12))
plt.subplot(2,3,1)
sns.boxplot(x='active', y='ap_lo', hue='cardio', data=df, palette='deep');
plt.title('Boxplot Atividade Física x Pressão Baixa')
plt.xlabel('Atividade Física')
plt.ylabel('Pressão Baixa');

plt.subplot(2,3,2)
sns.boxplot(x='active', y='ap_hi', hue='cardio', data=df, palette='deep');
plt.title('Boxplot Atividade Física x Pressão Alta')
plt.xlabel('Atividade Física')
plt.ylabel('Pressão Alta');

plt.subplot(2,3,3)
sns.boxplot(x='active', y='age', hue='cardio', data=df, palette='deep');
plt.title('Boxplot Atividade Física x Idade')
plt.xlabel('Atividade Física')
plt.ylabel('Idade');

plt.subplot(2,3,4)
sns.boxplot(x='active', y='weight', hue='cardio', data=df, palette='deep');
plt.title('Boxplot Atividade Física x Peso')
plt.xlabel('Atividade Física')
plt.ylabel('Peso');

plt.subplot(2,3,5)
sns.boxplot(x='active', y='height', hue='cardio', data=df, palette='deep');
plt.title('Boxplot Atividade Física x Altura')
plt.xlabel('Atividade Física')
plt.ylabel('Altura');

plt.subplot(2,3,6)
aux = df[(df['imc']<60)]
sns.boxplot(x='active', y='imc', hue='cardio', data=aux, palette='deep');
plt.title('Boxplot Atividade Física x IMC')
plt.xlabel('Atividade Física')
plt.ylabel('IMC');

# %% [markdown]
# ### 3.1.11 - Variável Influence Comorbid Activities - Influência da atividade física em quem tem comorbidades

# %%
fig, ax = plt.subplots(1, 2, figsize=(18,4))
sns.countplot(x='influence comorbid activities', hue='cardio', data=df, palette='Greens', ax=ax[0], 
              order = df['influence comorbid activities'].value_counts().index);
ax[0].set_title('Fatores de Risco', fontsize=20)
ax[0].set_xlabel('Fatores de Risco', fontsize=15)
ax[0].tick_params(labelrotation=90)
ax[0].set_ylabel('Total', fontsize=15);

aux = df[['influence comorbid activities', 'cardio']].groupby('influence comorbid activities').count().reset_index()
hue1 = df[(df['influence comorbid activities']=='Não faz atividade - 2 comorbidade') & (df['cardio']==1)].shape[0]
hue2 = df[(df['influence comorbid activities']=='Não faz atividade - 1 comorbidade') & (df['cardio']==1)].shape[0]
hue3 = df[(df['influence comorbid activities']=='Não faz atividade - Nenhuma comorbidade') & (df['cardio']==1)].shape[0]
hue4 = df[(df['influence comorbid activities']=='Faz atividade - 2 comorbidade') & (df['cardio']==1)].shape[0]
hue5 = df[(df['influence comorbid activities']=='Faz atividade - 1 comorbidade') & (df['cardio']==1)].shape[0]
hue6 = df[(df['influence comorbid activities']=='Faz atividade - Nenhuma comorbidade') & (df['cardio']==1)].shape[0]
hue = pd.DataFrame([hue5, hue4, hue6, hue2, hue1, hue3])
aux1 = pd.concat([aux, hue], axis=1)
aux1['media'] = aux1[0]/aux1['cardio']
aux1['media'] = aux1['media']*100
aux1 = aux1[['influence comorbid activities', 'media']]
aux1.set_index('influence comorbid activities',inplace=True)
aux1 = aux1.sort_values(by='media', ascending=False)
aux1.plot.bar(ax=ax[1], color='Green');
ax[1].set_title('Casos de problemas no coração em média', fontsize=20)
ax[1].set_xlabel('Fatores de Risco', fontsize=15)
ax[1].tick_params(labelrotation=90)
ax[1].set_ylabel('Percentual', fontsize=15);

# %% [markdown]
# **Teste de Hipótese**
#
# A distribuição das pessoas que fazem atividade física  e tem comorbidade é diferente da distribuição das pessoas que não fazem?:
#
# **<p>H0** - A distribuição é igual</p>
# **H1** - A distribuição é diferente
#
# **Teste T**

# %%
aux1['media']
# Out:
# influence comorbid activities
# Não faz atividade - 2 comorbidade          69.502911
# Faz atividade - 2 comorbidade              69.306516
# Não faz atividade - 1 comorbidade          62.938727
# Faz atividade - 1 comorbidade              58.621205
# Não faz atividade - Nenhuma comorbidade    48.877585
# Faz atividade - Nenhuma comorbidade        42.863759
# Name: media, dtype: float64

# %%
atividade_nao = [69.506726, 62.991657, 48.914248 ]
atividade_sim = [69.302668, 58.647068, 42.852070]

# %%
_, p = stats.ttest_ind(atividade_nao,atividade_sim)
alpha = 0.05
if p > alpha:
    print('O valor de p é {}, por tanto as distribuições são iguais (falha ao rejeitar H0)'.format(p))
else:
    print('O valor de p é {}, portanto as distribuições são diferentes (rejeitar H0)'.format(p))
# Out:
# O valor de p é 0.7363178876380922, por tanto as distribuições são iguais (falha ao rejeitar H0)

# %% [markdown]
# **Anotações Importantes**
#
# - Fazer atividade física não faz diferença para quem tem comorbidades.
# - Logo, quem não tem comorbidade tem menos chances de problemas no coração (mesmo que não façam atividades).

# %% [markdown]
# ### 3.1.12 - Variável influence bad habits activities - Influência da atividade física em quem tem maus hábitos

# %%
fig, ax = plt.subplots(1, 2, figsize=(18,4))
sns.countplot(x='influence bad habits activities', hue='cardio', data=df, ax=ax[0], palette= "Reds",
             order = df['influence bad habits activities'].value_counts().index);
ax[0].set_title('Fatores de Risco', fontsize=20)
ax[0].set_xlabel('Fatores de Risco', fontsize=15)
ax[0].tick_params(labelrotation=90)
ax[0].set_ylabel('Total', fontsize=15)

aux = df[['influence bad habits activities', 'cardio']].groupby('influence bad habits activities').count().reset_index()
hue1 = df[(df['influence bad habits activities']=='Não faz atividade - 2 maus hábitos') & (df['cardio']==1)].shape[0]
hue2 = df[(df['influence bad habits activities']=='Não faz atividade - 1 mau hábitos') & (df['cardio']==1)].shape[0]
hue3 = df[(df['influence bad habits activities']=='Não faz atividade - Nenhum mau hábitos') & (df['cardio']==1)].shape[0]
hue4 = df[(df['influence bad habits activities']=='Faz atividade - 2 maus hábitos') & (df['cardio']==1)].shape[0]
hue5 = df[(df['influence bad habits activities']=='Faz atividade - 1 mau hábitos') & (df['cardio']==1)].shape[0]
hue6 = df[(df['influence bad habits activities']=='Faz atividade - Nenhum mau hábitos') & (df['cardio']==1)].shape[0]
hue = pd.DataFrame([hue5,hue4, hue6, hue2, hue1, hue3])
aux1 = pd.concat([aux, hue], axis=1)
aux1['media'] = aux1[0]/aux1['cardio']
aux1['media'] = aux1['media']*100
aux1 = aux1[['influence bad habits activities', 'media']]
aux1.set_index('influence bad habits activities',inplace=True)
aux1 = aux1.sort_values(by='media', ascending=False)
aux1.plot.bar(ax=ax[1], color='red');
ax[1].set_title('Casos de problemas no coração em média', fontsize=20)
ax[1].set_xlabel('Fatores de Risco', fontsize=15)
ax[1].tick_params(labelrotation=90)
ax[1].set_ylabel('Percentual', fontsize=15);

# %% [markdown]
# **Teste de Hipótese**
#
# A distribuição das pessoas que fazem atividade física é diferente da distribuição das pessoas que bão fazem?:
#
# **<p>H0** - A distribuição é igual</p>
# **H1** - A distribuição é diferente
#
# **Teste T**

# %%
aux1['media']
# Out:
# influence bad habits activities
# Não faz atividade - 2 maus hábitos        55.555556
# Não faz atividade - 1 mau hábitos         55.384615
# Não faz atividade - Nenhum mau hábitos    54.132514
# Faz atividade - Nenhum mau hábitos        49.874342
# Faz atividade - 1 mau hábitos             49.316187
# Faz atividade - 2 maus hábitos            42.732167
# Name: media, dtype: float64

# %%
atividade_nao = [55.555556, 55.452675, 54.165241 ]
atividade_sim = [49.867551, 49.293756, 42.818611]

# %%
_, p = stats.ttest_ind(atividade_nao,atividade_sim)
alpha = 0.05
if p > alpha:
    print('O valor de p é {}, por tanto as distribuições são iguais (falha ao rejeitar H0)'.format(p))
else:
    print('O valor de p é {}, portanto as distribuições são diferentes (rejeitar H0)'.format(p))
# Out:
# O valor de p é 0.028419150723093166, portanto as distribuições são diferentes (rejeitar H0)

# %% [markdown]
# **Anotações Importantes**
#
# - A atividade física diminui os casos de doença do coração em média para quem tem maus hábitos.

# %% [markdown]
# ### 3.1.13 - IMC

# %%
plt.figure(figsize=(18,6))
plt.subplot(1,3,1)
aux = df[(df['imc']<50)]
sns.boxplot(x='cardio', y='imc', data=aux, palette="PRGn")

plt.subplot(1,3,2)
sns.scatterplot(x='imc', y='ap_hi', hue='cardio', data=df,palette="YlOrRd" )

plt.subplot(1,3,3)
sns.scatterplot(x='imc', y='ap_lo', hue='cardio', data=df, palette="YlOrRd");

# %% [markdown]
# **Anotações Importantes**
#
# - Quem tem problema no coração tem o IMC mais alto em média.
# - Quem tem problema no coração parece ter uma pressão alta maior.

# %% [markdown]
# ### Distribuição do IMC

# %%
aux = df[(df['imc']<100)]
plt.figure(figsize=(18,6))
sns.distplot(x=aux['imc'], kde=True);

# %% [markdown]
# ### 3.1.14 - Nível de Obesidade

# %%
plt.figure(figsize=(18,6))
sns.countplot(x='obesity', hue='cardio', data=df, palette='Blues',
             order = df['obesity'].value_counts().index);

# %% [markdown]
# ### Boxplot Nivel Obesidade

# %%
plt.figure(figsize=(18,6))
sns.boxplot(x='obesity', y='age', hue='cardio',data=df, palette='deep');

# %% [markdown]
# **Anotações Importantes**
#
# - Independente do nível de obesidade, quem teve mais problemas cardíacos são sempre pessoas de mais idade em media.

# %% [markdown]
# ### 3.2 - Distribuição das variáveis

# %%
df1 = df.drop(['id'], axis=1)
fig = plt.figure(figsize=(14,14))
ax = fig.gca()
df1.hist(ax=ax, color='black');

# %% [markdown]
# ## 3.2 Análise Bivariada

# %% [markdown]
# **H1 -** Pessoas com mais de 60 anos tem duas vezes mais chances de ter problema no coração do que uma pessoa com menos de 60 anos.
#
# **Falso** - Pessoas com mais de 60 anos tem em média sete vezes mais chances de ter problemas no coração.

# %%
df['faixa_etaria'] = df['age'].apply(lambda x: 'acima de 60' if x >= 60 else 'abaixo de 60')
aux = df[['faixa_etaria', 'cardio']].groupby('faixa_etaria').count().reset_index()

hue1 = df[(df['faixa_etaria']=='acima de 60') & (df['cardio']==1)].shape[0]
hue2 = df[(df['faixa_etaria']=='abaixo de 60') & (df['cardio']==1)].shape[0]

hue = pd.DataFrame([hue1,hue2])
aux = pd.concat([aux, hue], axis=1)

aux['media'] = aux[0]/aux['cardio']
aux = aux[['faixa_etaria', 'media']]
aux.set_index('faixa_etaria',inplace=True)
fig, ax = plt.subplots(1, 2, figsize=(18,4))
aux.plot.bar(ax=ax[1]);
ax[1].set_title('Casos de Problemas no Coração em Média')
ax[1].set_xlabel('Abaixo de 60 anos X Acima de 60 anos')
plt.xticks(rotation = 0)
ax[1].set_ylabel('Total');

sns.countplot(x='faixa_etaria', data=df, palette='winter_r', ax=ax[0]);
ax[0].set_title('Casos de Problemas no Coração')
ax[0].set_xlabel('Abaixo de 60 anos X Acima de 60 anos')
ax[0].set_ylabel('Total');

# %% [markdown]
# **H2 -** Em média, um gênero tem mais chances de ter problema no coração do que o outro.
#
# **Falso** - Homens e mulheres tem a mesma chance de ter problemas no coração.

# %%
sns.countplot(x='gender', hue='cardio', data=df, palette='inferno_r');

# %% [markdown]
# **H3 -** Pressão alta acima de 140 aumenta duas vezes o risco de ter problema no coração.
#
# **Falso** - Pressão alta acima de 140 aumenta três vezes o risco de ter problemas no coração.

# %%
df['faixa_ap_hi'] = df['ap_hi'].apply(lambda x: 'Pressão Alta Acima de 140' if x >= 140 else 'Pressão Alta Abaixo de 140')
aux = df[['faixa_ap_hi', 'cardio']].groupby('faixa_ap_hi').count().reset_index()

hue1 = df[(df['faixa_ap_hi']=='Pressão Alta Acima de 140') & (df['cardio']==1)].shape[0]
hue2 = df[(df['faixa_ap_hi']=='Pressão Alta Abaixo de 140') & (df['cardio']==1)].shape[0]

hue = pd.DataFrame([hue1,hue2])
aux = pd.concat([aux, hue], axis=1)

aux['media'] = aux[0]/aux['cardio']
aux = aux[['faixa_ap_hi', 'media']]
aux.set_index('faixa_ap_hi',inplace=True)
fig, ax = plt.subplots(1, 2, figsize=(18,4))
aux.plot.bar(ax=ax[1]);
ax[1].set_title('Casos de Problemas no Coração em Média')
ax[1].set_xlabel('Pressão alta abaixo de 140mm X pressão alta acima de 140mm')
plt.xticks(rotation = 0)
ax[1].set_ylabel('Total de Casos');

sns.countplot(x='faixa_ap_hi', data=df, palette='winter_r', ax=ax[0]);
ax[0].set_title('Casos de Problemas no Coração')
ax[0].set_xlabel('Pressão alta acima de 140mm X Pressão alta abaixo de 140mm')
ax[0].set_ylabel('Total de Casos');

# %% [markdown]
# **H4 -** Pressão baixa acima de 80 aumenta duas vezes o risco de ter problema no coração.
#
# **Falso** - Em média, a maioria dos casos de problema no coração é em quem tem uma pressão baixa abaixo de 80mm.

# %%
df['faixa_ap_lo'] = df['ap_lo'].apply(lambda x: 'Pressão Baixa Acima de 80' if x >= 80 else 'Pressão Baixa Abaixo de 80')
aux = df[['faixa_ap_lo', 'cardio']].groupby('faixa_ap_lo').count().reset_index()

hue1 = df[(df['faixa_ap_lo']=='Pressão Baixa Acima de 80') & (df['cardio']==1)].shape[0]
hue2 = df[(df['faixa_ap_lo']=='Pressão Baixa Abaixo de 80') & (df['cardio']==1)].shape[0]

hue = pd.DataFrame([hue1,hue2])
aux = pd.concat([aux, hue], axis=1)

aux['media'] = aux[0]/aux['cardio']
aux = aux[['faixa_ap_lo', 'media']]
aux.set_index('faixa_ap_lo',inplace=True)
fig, ax = plt.subplots(1, 2, figsize=(18,4))
aux.plot.bar(ax=ax[1]);
ax[1].set_title('Casos de Problemas no Coração em Média')
ax[1].set_xlabel('Pressão baixa abaixo de 80mm X pressão baixa acima de 80mm')
plt.xticks(rotation = 0)
ax[1].set_ylabel('Total de Casos');

sns.countplot(x='faixa_ap_lo', data=df, palette='winter_r', ax=ax[0]);
ax[0].set_title('Casos de Problemas no Coração')
ax[0].set_xlabel('Pressão baixa acima de 80mm X Pressão baixa abaixo de 80mm')
ax[0].set_ylabel('Total de Casos');

# %% [markdown]
# ## 3.3 - Análise Multivariada

# %%
corr = df.corr()
plt.figure(figsize=(18,6))
sns.heatmap(corr, annot=True, cmap="Blues");

# %% [markdown]
# # Anotações importante dos dados

# %% [markdown]
# **Todas as anotações importantes**
#
# - Os dados da variável resposta estão balanceados.
# - Os pacientes que possuem doenças cardíacas possuem uma média de idade maior do que os pacientes que não possuem.
# - A Distribuição das idades de quem possui e de quem não possui doença cardíaca é diferente (indica ser uma boa variável).
# - O dataset tem mais exemplos de um dos genêros.
# - Media dos KG de quem tem problema no coração é maior.
# - A Distribuição do peso de quem tem problemas cardíacos e de quem não tem problemas cardíacos é diferente.
# - O peso de quem tem problema no coração tem diferença estatísticamente significativa.
# - Quem tem pressão alta maior parece ter mais chances de ter problemas no coração.
# - Quem tem uma pressão baixa menor e uma idade menor tem mais chances de NÃO ter problemas no coração.
# - A Grande maioria das pessoas da base de dados não bebem alcool.
# - A Grande maioria das pessoas da base de dados não fumam.
# - Para um mesmo número de comorbidade a atividade física parece fazer diferença (mesmo que pouca).
# - Quem não tem comorbidade parece ter menos chances de problemas no coração (mesmo que façam atividades).
# - Fazer atividade física não faz diferença para quem tem comorbidades.
# - Logo, quem não tem comorbidade tem menos chances de problemas no coração (mesmo que não façam atividades).
# - A atividade física diminui os casos de doença do coração em média para quem tem maus hábitos.
# - Independente do nível de obesidade, quem teve mais problemas cardíacos são sempre pessoas de mais idade em media.

# %% [markdown]
# # 5.0 - Preparação dos Dados

# %%
df.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio',
#        'sum of factors', 'bad habits', 'influence comorbid activities',
#        'influence bad habits activities', 'imc', 'obesity', 'hi_per_low',
#        'faixa_etaria', 'faixa_ap_hi', 'faixa_ap_lo'],
#       dtype='object')

# %%
X = df.drop(['cardio'], axis=1)
y = df['cardio']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
df_train = pd.concat([X_train, y_train], axis=1)
df_test = pd.concat([X_test, y_test], axis=1)

# %%
df_train1 = df_train.copy()
df_test1 = df_test.copy()

# %% [markdown]
# ## 4.1 - Standardization Dados de Treino

# %%
ss_height = StandardScaler()
ss_weight = StandardScaler()
ss_ap_hi = StandardScaler()
ss_ap_lo = StandardScaler()
ss_imc = StandardScaler()
ss_hi_per_low = StandardScaler()

df_train1['ap_hi'] = ss_ap_hi.fit_transform(df_train1[['ap_hi']].values)
df_train1['ap_lo'] = ss_ap_lo.fit_transform(df_train1[['ap_lo']].values)
df_train1['height'] = ss_height.fit_transform(df_train1[['height']].values)
df_train1['weight'] = ss_weight.fit_transform(df_train1[['weight']].values)
df_train1['imc'] = ss_imc.fit_transform(df_train1[['imc']].values)
df_train1['hi_per_low'] = ss_hi_per_low.fit_transform(df_train1[['hi_per_low']].values)

# %% [markdown]
# ## 4.2 - Rescalling Dados de Treino

# %%
mms_age = MinMaxScaler()

df_train1['age'] = mms_age.fit_transform(df_train1[['age']].values)

# %% [markdown]
# ## 4.3 - Encoding Dados de Treino

# %%
# Frequency encoding - influence comorbid activities
fe_influence_comorbid_activities = df_train1.groupby('influence comorbid activities').size() / len(df_train1) 
df_train1.loc[:, 'influence comorbid activities'] = df_train1['influence comorbid activities'].map(fe_influence_comorbid_activities)

# Frequency encoding - influence bad habits activities
fe_influence_bad_habits_activities = df_train1.groupby('influence bad habits activities').size() / len(df_train1) 
df_train1.loc[:, 'influence bad habits activities'] = df_train1['influence bad habits activities'].map(fe_influence_bad_habits_activities)

# Frequency encoding - obesity
fe_obesity = df_train1.groupby('obesity').size() / len(df_train1) 
df_train1.loc[:, 'obesity'] = df_train1['obesity'].map(fe_obesity)

# %%
df_train_dummies = df_train1[['faixa_etaria', 'faixa_ap_hi', 'faixa_ap_lo']]
df_train_dummies = pd.get_dummies(df_train_dummies)
df_train1 = df_train1.drop(['faixa_etaria', 'faixa_ap_hi', 'faixa_ap_lo'],axis=1)
df_train1 = pd.concat([df_train1,df_train_dummies], axis=1)

# %% [markdown]
# ## 4.4 -  Standardization Dados de Teste

# %%
df_test1.loc[:, 'ap_hi'] = ss_ap_hi.transform(df_test1[['ap_hi']].values)

df_test1.loc[:, 'ap_lo'] = ss_ap_lo.transform(df_test1[['ap_lo']].values)

df_test1.loc[:, 'height'] = ss_height.transform(df_test1[['height']].values)

df_test1.loc[:, 'weight'] = ss_weight.transform(df_test1[['weight']].values)

df_test1.loc[:, 'imc'] = ss_weight.transform(df_test1[['imc']].values)

df_test1.loc[:, 'hi_per_low'] = ss_weight.transform(df_test1[['hi_per_low']].values)

# %% [markdown]
# ## 4.5 - Rescalling Dados de Teste

# %%
df_test1.loc[:, 'age'] = mms_age.transform(df_test1[['age']].values)

# %% [markdown]
# ## 4.6 - Encoding Dados de Teste

# %%
df_test1.loc[:, 'influence comorbid activities'] = df_test1['influence comorbid activities'].map(fe_influence_comorbid_activities)

df_test1.loc[:, 'influence bad habits activities'] = df_test1['influence bad habits activities'].map(fe_influence_bad_habits_activities)

df_test1.loc[:, 'obesity'] = df_test1['obesity'].map(fe_obesity)

# %%
df_test_dummies = df_test1[['faixa_etaria', 'faixa_ap_hi', 'faixa_ap_lo']]
df_test_dummies = pd.get_dummies(df_test_dummies)
df_test1 = df_test1.drop(['faixa_etaria', 'faixa_ap_hi', 'faixa_ap_lo'],axis=1)
df_test1 = pd.concat([df_test1,df_test_dummies], axis=1)

# %% [markdown]
# # 6.0 - Feature Selection

# %% [markdown]
# ## Feature Importance Random Forest

# %%
X_train_feature_importance = df_train1.drop(['cardio', 'id'], axis=1)
y_train_feature_importance = df_train1['cardio']

# %%
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train_feature_importance, y_train_feature_importance)

# feature importance data frame
feat_imp = pd.DataFrame({'feature': X_train_feature_importance.columns,
                        'feature_importance': rf.feature_importances_})\
                        .sort_values('feature_importance', ascending=False)\
                        .reset_index(drop=True)


# plot feature importance
plt.subplots(figsize=(12,6))
sns.barplot(x='feature_importance', y='feature', data=feat_imp, orient='h', color='red')\
    .set_title('Feature Importance');

# %%
cols_importance_forest = ['imc', 'weight','height', 'age', 'ap_hi', 'faixa_ap_hi_Pressão Alta Abaixo de 140',
                          'faixa_ap_hi_Pressão Alta Acima de 140','ap_lo', 'hi_per_low']

# %% [markdown]
# ## Boruta

# %%
extra_clf = ExtraTreesClassifier()

# %%
boruta = BorutaPy(extra_clf, n_estimators='auto', verbose=2, random_state=42).fit(X_train_feature_importance.values, 
                                                                                  y_train_feature_importance.values)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	24
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	24
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	24
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	24
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	24
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	24
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	24
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	6
# Tentative: 	0
# Rejected: 	18
#
#
# BorutaPy finished running.
#
# Iteration: 	9 / 100
# Confirmed: 	6
# Tentative: 	0
# Rejected: 	18

# %%
#checking feature importances
extra_clf.fit(X_train_feature_importance, y_train_feature_importance)

feat_importances = pd.Series(extra_clf.feature_importances_, index=X_train_feature_importance.columns)
plt.subplots(figsize=(12,6))
feat_importances.sort_values().plot(kind='barh');

# %%
# gets the ranked list of features
cols_selected = boruta.support_.tolist()
cols_selected_boruta = X_train_feature_importance.iloc[:, cols_selected].columns.to_list()
cols_selected_boruta
# Out:
# ['age',
#  'weight',
#  'ap_hi',
#  'imc',
#  'faixa_ap_hi_Pressão Alta Abaixo de 140',
#  'faixa_ap_hi_Pressão Alta Acima de 140']

# %%
cols_boruta = ['age', 'weight', 'ap_hi', 'imc', 'faixa_ap_hi_Pressão Alta Abaixo de 140',
               'faixa_ap_hi_Pressão Alta Acima de 140', 'hi_per_low']

# %%
X_train_forest = df_train1[cols_boruta]

X_test_forest = df_test1[cols_boruta]

# %% [markdown]
# # 7.0 - Machine Learning

# %%
du = DummyClassifier()
lr = LogisticRegression()
dtc = DecisionTreeClassifier()
etx = ExtraTreesClassifier()
rfc = RandomForestClassifier()
gbc = GradientBoostingClassifier()
knn = KNeighborsClassifier()
lgbm = LGBMClassifier()
sgdc = SGDClassifier()

# %%
lr_result_forest = ml_error('Regressão Logistica',lr, X_train_forest, y_train)
lr_result_forest
# Out:
#             Model_Name  Acuracia  Precision    Recall   ROC_AUC        F1
# 0  Regressão Logistica    0.7134   0.767538  0.621026  0.714426  0.686499

# %%
dtc_result_forest = ml_error('DecisionTreeClassifier',dtc, X_train_forest, y_train)
dtc_result_forest
# Out:
#                Model_Name  Acuracia  Precision    Recall   ROC_AUC        F1
# 0  DecisionTreeClassifier  0.630997    0.64418  0.602743  0.631294  0.622764

# %%
etx_result_forest = ml_error('ExtraTreesClassifier',etx, X_train_forest, y_train)
etx_result_forest
# Out:
#              Model_Name  Acuracia  Precision    Recall   ROC_AUC        F1
# 0  ExtraTreesClassifier  0.669673   0.678584  0.658054  0.669808  0.668146

# %%
rfc_result_forest = ml_error('RandomForestClassifier',rfc, X_train_forest, y_train)
rfc_result_forest
# Out:
#                Model_Name  Acuracia  Precision    Recall   ROC_AUC        F1
# 0  RandomForestClassifier  0.679732   0.685485  0.676753  0.679769  0.681073

# %%
gbc_result_forest = ml_error('GradientBoostingClassifier',gbc, X_train_forest, y_train)
gbc_result_forest
# Out:
#                    Model_Name  Acuracia  Precision    Recall   ROC_AUC  \
# 0  GradientBoostingClassifier  0.720706    0.73814  0.693368  0.721026
#
#          F1
# 0  0.715018

# %%
knn_result_forest = ml_error('KNN', knn, X_train_forest, y_train)
knn_result_forest
# Out:
#   Model_Name  Acuracia  Precision    Recall   ROC_AUC        F1
# 0        KNN  0.679689    0.68606  0.675173  0.679747  0.680549

# %%
lgbm_result_forest = ml_error('LGBM', lgbm, X_train_forest, y_train)
lgbm_result_forest
# Out:
#   Model_Name  Acuracia  Precision    Recall   ROC_AUC        F1
# 0       LGBM  0.718863   0.737687  0.688648  0.719216  0.712279

# %%
sgdc_result_forest = ml_error('SGDClassifier', sgdc, X_train_forest, y_train)
sgdc_result_forest
# Out:
#       Model_Name  Acuracia  Precision    Recall   ROC_AUC       F1
# 0  SGDClassifier  0.683222   0.836637  0.463707  0.685593  0.59663

# %%
modelling_result_forest = pd.concat([lr_result_forest, dtc_result_forest, etx_result_forest, rfc_result_forest, 
                                     gbc_result_forest,knn_result_forest, lgbm_result_forest, sgdc_result_forest])
modelling_result_forest.sort_values('F1', ascending=False)
# Out:
#                    Model_Name  Acuracia  Precision    Recall   ROC_AUC  \
# 0  GradientBoostingClassifier  0.720706   0.738140  0.693368  0.721026
# 0                        LGBM  0.718863   0.737687  0.688648  0.719216
# 0         Regressão Logistica  0.713400   0.767538  0.621026  0.714426
# 0      RandomForestClassifier  0.679732   0.685485  0.676753  0.679769
# 0                         KNN  0.679689   0.686060  0.675173  0.679747
# 0        ExtraTreesClassifier  0.669673   0.678584  0.658054  0.669808
# 0      DecisionTreeClassifier  0.630997   0.644180  0.602743  0.631294
# 0               SGDClassifier  0.683222   0.836637  0.463707  0.685593
#
#          F1
# 0  0.715018
# 0  0.712279
# 0  0.686499
# 0  0.681073
# 0  0.680549
# 0  0.668146
# 0  0.622764
# 0  0.596630

# %% [markdown]
# **Modelos Selecionados**
#
# - GradientBoostingClassifier
# - LGBM
# - Regressão Logistica

# %% [markdown]
# ## 7.2 Matriz de Confusão dos modelos escolhidos

# %%
classifiers = [LogisticRegression(),GradientBoostingClassifier(), LGBMClassifier()]

# %%
multiple_confusion_matrix(classifiers, X_train_forest, X_test_forest)

# %%
gbc.fit(X_train_forest, y_train)
# Out:
# GradientBoostingClassifier()

# %%
lgbm.fit(X_train_forest, y_train)
# Out:
# LGBMClassifier()

# %%
lr.fit(X_train_forest, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_gbc_prob = gbc.predict_proba(X_test_forest)[:,1]
y_pred_lgbm_prob = lgbm.predict_proba(X_test_forest)[:,1]
y_pred_lr_prob = lr.predict_proba(X_test_forest)[:,1]

# %% [markdown]
# ## 7.3 - Curva ROC

# %%
# uses the variable ax for single a Axes
fig, ax = plt.subplots()

# sets the figure size in inches
ax.figure.set_size_inches(10, 6)

# generate a no skill prediction (majority class)
ns_probs = [0 for _ in range(len(y_test))]

# calculates the roc curves
ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
gbc_fpr, gbc_tpr, _ = roc_curve(y_test, y_pred_gbc_prob)
lr_fpr, lr_tpr, _ = roc_curve(y_test, y_pred_lr_prob)
lgbm_fpr, lgbm_tpr, _ = roc_curve(y_test, y_pred_lgbm_prob)


# plots the roc curve for the model
plt.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')
plt.plot(gbc_fpr, gbc_tpr, marker='.', label='Gradient')
plt.plot(lr_fpr, lr_tpr, marker='.', label='logistica')
plt.plot(lgbm_fpr, lgbm_tpr, marker='.', label='LGBM')

# sets plot features
plt.title("ROC Curve", fontsize=14)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

# displays the legend
plt.legend()

# displays the plot
plt.show()

# %% [markdown]
# ## 7.4 - Densidade de Probabilidade

# %%
# sets the plot size
plt.figure(figsize=(10,6))

# plots
sns.kdeplot(y_pred_gbc_prob, label='Gradient')
sns.kdeplot(y_pred_lr_prob, label='LR')
sns.kdeplot(y_pred_lgbm_prob, label='LGBM')

# sets the plot features
plt.title("Probability Density Plot", fontsize=14)
plt.legend()

# display the plot
plt.show()

# %% [markdown]
# ## 7.5 Brier Score

# %%
bsl_rf = brier_score_loss(y_test, y_pred_gbc_prob, pos_label=1)
bsl_sgd = brier_score_loss(y_test, y_pred_lr_prob, pos_label=1)
bsl_lgbm = brier_score_loss(y_test, y_pred_lgbm_prob, pos_label=1)

# prints the calculated Brier Score Loss for each algorithm probability
print(f'Brier Score Loss (gradient): {bsl_rf}')
print(f'Brier Score Loss (lr): {bsl_sgd}')
print(f'Brier Score Loss (LGBM): {bsl_lgbm}')
# Out:
# Brier Score Loss (gradient): 0.20408205060729823
# Brier Score Loss (lr): 0.19541678669603252
# Brier Score Loss (LGBM): 0.2046681645609665

# %% [markdown]
# # 8.0 - Hyper Tunning

# %% [markdown]
# ## 8.1 - Parametros Grid

# %%
kfold=20
param_grid = [{'penalty':['l2', 'l1','elasticnet', 'none'], 'C':[1,5, 10],
               'solver':['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']}]
grid = GridSearchCV(lr, param_grid, cv=kfold)
grid.fit(X_train_forest,y_train)
# Out:
# GridSearchCV(cv=10, estimator=LogisticRegression(),
#              param_grid=[{'C': [1, 5, 10],
#                           'penalty': ['l2', 'l1', 'elasticnet', 'none'],
#                           'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                      'saga']}])

# %%
grid.best_params_
# Out:
# {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
lor = LogisticRegression(penalty='l1', C=1, solver='liblinear')

# %%
lor.fit(X_train_forest, y_train)
# Out:
# LogisticRegression(C=1, penalty='l1', solver='liblinear')

# %%
pred = lor.predict(X_test_forest)

# %%
skplt.metrics.plot_confusion_matrix(y_test, pred,normalize=True, labels=[0,1]);

# %%
cv = StratifiedKFold(n_splits=10)

# %%
# calculates the cross validation scores
cv_scores = cross_val_score(lor, X_train_forest, y_train, cv = cv, scoring='precision', n_jobs=-1)

# prints the average precision and standard deviation of the scores
print("Average precision: %0.4f (+/- %0.4f)" % (cv_scores.mean(), cv_scores.std() * 2))


# calculates the cross validation scores
cv_scores = cross_val_score(lor, X_train_forest, y_train, cv = cv, scoring='recall', n_jobs=-1)

# prints the average recall and standard deviation of the scores
print("\nAverage recall: %0.4f (+/- %0.4f)" % (cv_scores.mean(), cv_scores.std() * 2))


# calculates the cross validation scores
cv_scores = cross_val_score(lor, X_train_forest, y_train, cv = cv, scoring='f1', n_jobs=-1)

# prints the average f1-score and standard deviation of the scores
print("\nAverage f1-score: %0.4f (+/- %0.4f)" % (cv_scores.mean(), cv_scores.std() * 2))

# calculates the cross validation scores
cv_scores = cross_val_score(lor, X_train_forest, y_train, cv = cv, scoring='roc_auc', n_jobs=-1)

# prints the average roc_auc and standard deviation of the scores
print("\nAverage ROC AUC: %0.4f (+/- %0.4f)" % (cv_scores.mean(), cv_scores.std() * 2))
# Out:
# Average precision: 0.7680 (+/- 0.0245)
#
# Average recall: 0.6216 (+/- 0.0203)
#
# Average f1-score: 0.6871 (+/- 0.0211)
#
# Average ROC AUC: 0.7803 (+/- 0.0177)

# %%
cv_scores = cross_val_score(lor, X_train_forest, y_train, cv = cv, scoring='precision', n_jobs=-1)

# %%
price_per_percent = 500/5
baseline = 50
num_pacients = 70000

# %%
model_accuracy = cv_scores.mean()
deviation = cv_scores.std() * 2

# %%
accuracy_lower = (model_accuracy - deviation) * 100
accuracy_upper = (model_accuracy + deviation) * 100

percent_difference_lower = accuracy_lower - baseline
percent_difference_upper = accuracy_upper - baseline

amount_best = percent_difference_upper * price_per_percent * num_pacients
amount_worst = percent_difference_lower * price_per_percent * num_pacients

# %%
print(f'Best:  ${round(amount_best, 2):,.2f}')
print(f'Worst: ${round(amount_worst, 2):,.2f}')
# Out:
# Best:  $204,841,513.50
# Worst: $170,402,561.86

# %% [markdown]
# |                                            | Avg Precision             | Avg Recall                | Avg f1\-score             | Avg ROC AUC               |
# |--------------------------------------------|---------------------------|---------------------------|---------------------------|---------------------------|
# | Regressão Logística | 0\.7680 \(\+/\- 0\.0245\) | 0\.6216 \(\+/\- 0\.0203\) | 0\.6871 \(\+/\- 0\.0211\) | 0\.7803 \(\+/\- 0\.0177\) |

# %% [markdown]
# |                        | Melhor cenário    | Pior cenário      |
# |:-----------------------|------------------:|------------------:|
# | Modelo Machine Learning| \$204,841,513.50  | \$170,402,561.86  |
# | Como está hoje         | \$105,000,000.00  | \$35,000,000.00   |

# %%
pickle.dump(lor, open('model/logistic_regression.pkl', 'wb'))
